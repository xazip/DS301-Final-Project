# %%
import sklearn
assert sklearn.__version__>= '0.20'

try:
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
assert tf.__version__>= '2.0'

from tensorflow import keras
# Out:
# TensorFlow 2.x selected.

# %%
#Check to make sure versions are correct
tf.__version__, keras.__version__
# Out:
# ('2.0.0', '2.2.4-tf')

# %%
#Import standard libraries
import pandas as pd
import numpy as np
import os

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling

# %%
# Ignore annoying warnings
import warnings 
warnings.filterwarnings(action = 'ignore', message = '^internal gelsd')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import glob

# %%
path = r"/content/drive/My Drive/PeMS_Data_Folder/2008"
all_files = glob.glob(path + "/*.txt")

glue = []

for filename in all_files:
  df = pd.read_csv(filename,
                   names = ["TimeStamp", "StationId", "StationTotalFlow", "StationAvgOcc",
                            "StationAvgSpeed", "StationPercentObserved", "Lane1TotalFlow",
                            "Lane1AvgOcc", "Lane1AvgSpeed", "Lane1Observed", "Lane2TotalFlow",
                            "Lane2AvgOcc", "Lane2AvgSpeed", "Lane2Observed", "Lane3TotalFlow",
                            "Lane3AvgOcc", "Lane3AvgSpeed", "Lane3Observed", "Lane4TotalFlow",
                            "Lane4AvgOcc", "Lane4AvgSpeed", "Lane4Observed"],
                   usecols = np.arange(22))
  glue.append(df)

Data_Frame_2008 = pd.concat(glue, axis = 0, ignore_index = True) #2008 Loaded

# %%
path = r"/content/drive/My Drive/PeMS_Data_Folder/2009"
all_files = glob.glob(path + "/*.txt")

glue = []

for filename in all_files:
  df = pd.read_csv(filename,
                   names = ["TimeStamp", "StationId", "StationTotalFlow", "StationAvgOcc",
                            "StationAvgSpeed", "StationPercentObserved", "Lane1TotalFlow",
                            "Lane1AvgOcc", "Lane1AvgSpeed", "Lane1Observed", "Lane2TotalFlow",
                            "Lane2AvgOcc", "Lane2AvgSpeed", "Lane2Observed", "Lane3TotalFlow",
                            "Lane3AvgOcc", "Lane3AvgSpeed", "Lane3Observed", "Lane4TotalFlow",
                            "Lane4AvgOcc", "Lane4AvgSpeed", "Lane4Observed"],
                   usecols = np.arange(22))
  glue.append(df)

Data_Frame_2009 = pd.concat(glue, axis = 0, ignore_index = True) #2009 Loaded

# %%
path = r"/content/drive/My Drive/PeMS_Data_Folder/2010"
all_files = glob.glob(path + "/*.txt")

glue = []

for filename in all_files:
  df = pd.read_csv(filename,
                   names = ["TimeStamp", "StationId", "StationTotalFlow", "StationAvgOcc",
                            "StationAvgSpeed", "StationPercentObserved", "Lane1TotalFlow",
                            "Lane1AvgOcc", "Lane1AvgSpeed", "Lane1Observed", "Lane2TotalFlow",
                            "Lane2AvgOcc", "Lane2AvgSpeed", "Lane2Observed", "Lane3TotalFlow",
                            "Lane3AvgOcc", "Lane3AvgSpeed", "Lane3Observed", "Lane4TotalFlow",
                            "Lane4AvgOcc", "Lane4AvgSpeed", "Lane4Observed"],
                   usecols = np.arange(22))
  glue.append(df)

Data_Frame_2010 = pd.concat(glue, axis = 0, ignore_index = True) #2010 Loaded

# %%
path = r"/content/drive/My Drive/PeMS_Data_Folder/2011"
all_files = glob.glob(path + "/*.txt")

glue = []

for filename in all_files:
  df = pd.read_csv(filename,
                   names = ["TimeStamp", "StationId", "StationTotalFlow", "StationAvgOcc",
                            "StationAvgSpeed", "StationPercentObserved", "Lane1TotalFlow",
                            "Lane1AvgOcc", "Lane1AvgSpeed", "Lane1Observed", "Lane2TotalFlow",
                            "Lane2AvgOcc", "Lane2AvgSpeed", "Lane2Observed", "Lane3TotalFlow",
                            "Lane3AvgOcc", "Lane3AvgSpeed", "Lane3Observed", "Lane4TotalFlow",
                            "Lane4AvgOcc", "Lane4AvgSpeed", "Lane4Observed"],
                   usecols = np.arange(22))
  glue.append(df)

Data_Frame_2011 = pd.concat(glue, axis = 0, ignore_index = True) #2011 Loaded

# %%
path = r"/content/drive/My Drive/PeMS_Data_Folder/2012"
all_files = glob.glob(path + "/*.txt")

glue = []

for filename in all_files:
  df = pd.read_csv(filename,
                   names = ["TimeStamp", "StationId", "StationTotalFlow", "StationAvgOcc",
                            "StationAvgSpeed", "StationPercentObserved", "Lane1TotalFlow",
                            "Lane1AvgOcc", "Lane1AvgSpeed", "Lane1Observed", "Lane2TotalFlow",
                            "Lane2AvgOcc", "Lane2AvgSpeed", "Lane2Observed", "Lane3TotalFlow",
                            "Lane3AvgOcc", "Lane3AvgSpeed", "Lane3Observed", "Lane4TotalFlow",
                            "Lane4AvgOcc", "Lane4AvgSpeed", "Lane4Observed"],
                   usecols = np.arange(22))
  glue.append(df)

Data_Frame_2012 = pd.concat(glue, axis = 0, ignore_index = True) #2012 Loaded

# %%
path = r"/content/drive/My Drive/PeMS_Data_Folder/2013"
all_files = glob.glob(path + "/*.txt")

glue = []

for filename in all_files:
  df = pd.read_csv(filename,
                   names = ["TimeStamp", "StationId", "StationTotalFlow", "StationAvgOcc",
                            "StationAvgSpeed", "StationPercentObserved", "Lane1TotalFlow",
                            "Lane1AvgOcc", "Lane1AvgSpeed", "Lane1Observed", "Lane2TotalFlow",
                            "Lane2AvgOcc", "Lane2AvgSpeed", "Lane2Observed", "Lane3TotalFlow",
                            "Lane3AvgOcc", "Lane3AvgSpeed", "Lane3Observed", "Lane4TotalFlow",
                            "Lane4AvgOcc", "Lane4AvgSpeed", "Lane4Observed"],
                   usecols = np.arange(22))
  glue.append(df)

Data_Frame_2013 = pd.concat(glue, axis = 0, ignore_index = True) #2013 Loaded

# %%
df = pd.concat([Data_Frame_2008, Data_Frame_2009,
                    Data_Frame_2010, Data_Frame_2011,
                    Data_Frame_2012, Data_Frame_2013]) #Bind DataFrames by row in increasing order by year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20987845 entries, 0 to 3287987
# Data columns (total 22 columns):
# TimeStamp                 object
# StationId                 int64
# StationTotalFlow          int64
# StationAvgOcc             float64
# StationAvgSpeed           float64
# StationPercentObserved    int64
# Lane1TotalFlow            int64
# Lane1AvgOcc               float64
# Lane1AvgSpeed             float64
# Lane1Observed             int64
# Lane2TotalFlow            int64
# Lane2AvgOcc               float64
# Lane2AvgSpeed             float64
# Lane2Observed             int64
# Lane3TotalFlow            int64
# Lane3AvgOcc               float64
# Lane3AvgSpeed             float64
# Lane3Observed             int64
# Lane4TotalFlow            float64
# Lane4AvgOcc               float64
# Lane4AvgSpeed             float64
# Lane4Observed             float64
# dtypes: float64(12), int64(9), object(1)
# memory usage: 3.6+ GB

# %%
df.head()
# Out:
#           TimeStamp  StationId  ...  Lane4AvgSpeed  Lane4Observed
# 0  01/01/2008 00:00     716897  ...            NaN            NaN
# 1  01/01/2008 00:00     762347  ...           62.7            4.0
# 2  01/01/2008 00:00     716896  ...           62.7            4.0
# 3  01/01/2008 00:00     716899  ...            NaN            NaN
# 4  01/01/2008 00:00     716900  ...            NaN            NaN
#
# [5 rows x 22 columns]

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                c_prec = df[col].apply(lambda x: np.finfo(x).precision).max()
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max and c_prec == np.finfo(np.float16).precision:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max and c_prec == np.finfo(np.float32).precision:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

#Standard Memory Reducing Function.  Originally found this on kaggle about 2 years ago and have modified from time to time.

# %% [markdown]
# We have created a master dataset.  There is only 22 columns but 3 million observations for 22 columns is a large task to take on.

# %% [markdown]
# First off we shall deal with the missing data.
# Lane2AvgOcc and Lane2AvgSpeed are objects but they should be float values.
#
# This has something to do with 2014 data. Will remove for now

# %%
df = reduce_mem_usage(df) #Reduced Memory by 30%!

# %%
df['Lane4TotalFlow'].fillna((df['Lane4TotalFlow'].mean()), inplace=True)
df['Lane4AvgOcc'].fillna((df['Lane4AvgOcc'].mean()), inplace=True)
df['Lane4AvgSpeed'].fillna((df['Lane4AvgSpeed'].mean()), inplace=True)
df['Lane4Observed'].fillna((df['Lane4Observed'].mean()), inplace=True) #Fill in Missing values with there respective means

# %%
df["NewTimeStamp"] = pd.to_datetime(df["TimeStamp"]) #Create a TimeStamp

# %%
df['year'] = df['NewTimeStamp'].dt.year
df['month'] = df['NewTimeStamp'].dt.month
df['day'] = df['NewTimeStamp'].dt.day
df['hour'] = df['NewTimeStamp'].dt.hour
df['minute'] = df['NewTimeStamp'].dt.minute
df['dayofweek'] = df["NewTimeStamp"].dt.dayofweek #Extract Information from Time Stamp

# %%
def Sunday(dayofweek):
  if dayofweek == 1:
    return 3
  elif dayofweek == 2:
    return 4
  elif dayofweek == 3:
    return 5
  elif dayofweek == 4:
    return 6
  elif dayofweek == 5:
    return 7
  elif dayofweek == 6:
    return 1
  elif dayofweek == 0:
    return 2
  else:
    return dayofweek
  
df["dayofweek"] = df["dayofweek"].apply(Sunday)
df["dayofweek"].value_counts() # Convert day of the week from 0-6 to 1-7......(1 -> Sunday)......(7 -> Saturday)
# Out:
# 2    3004128
# 7    3004094
# 3    3003840
# 6    2994624
# 5    2994623
# 4    2994336
# 1    2992200
# Name: dayofweek, dtype: int64

# %%
df_wide = df.pivot_table(index = ["StationId", "day", "month", "year", "hour", "dayofweek"], columns = "minute", values = ["StationTotalFlow"])
#Create a Multi Index Dataframe
#This will help us parse the data how we want it.

# %%
df_wide.head()
# Out:
#                                         StationTotalFlow         ...
# minute                                                0      5   ...     50     55
# StationId day month year hour dayofweek                          ...
# 715915    1   1     2008 0    3                     82.0   78.0  ...  346.0  358.0
#                          1    3                    396.0  358.0  ...  359.0  318.0
#                          2    3                    324.0  204.0  ...  190.0  170.0
#                          3    3                    164.0  177.0  ...  113.0   80.0
#                          4    3                     96.0   80.0  ...  108.0  114.0
#
# [5 rows x 12 columns]

# %%
df_wide = df_wide.reset_index() # Flatten Dimensions

# %%
df_wide.head()
# Out:
#        StationId day month  year hour  ... StationTotalFlow
# minute                                 ...               35     40     45     50     55
# 0         715915   1     1  2008    0  ...            268.0  296.0  338.0  346.0  358.0
# 1         715915   1     1  2008    1  ...            325.0  369.0  367.0  359.0  318.0
# 2         715915   1     1  2008    2  ...            191.0  187.0  190.0  190.0  170.0
# 3         715915   1     1  2008    3  ...            103.0  125.0  129.0  113.0   80.0
# 4         715915   1     1  2008    4  ...            101.0   90.0   94.0  108.0  114.0
#
# [5 rows x 18 columns]

# %%
df_wide.columns = df_wide.columns.get_level_values(0) # Flatten Dimensions again
df_wide.head()  # We are now back into are original format
# Out:
#    StationId  day  month  ...  StationTotalFlow  StationTotalFlow  StationTotalFlow
# 0     715915    1      1  ...             338.0             346.0             358.0
# 1     715915    1      1  ...             367.0             359.0             318.0
# 2     715915    1      1  ...             190.0             190.0             170.0
# 3     715915    1      1  ...             129.0             113.0              80.0
# 4     715915    1      1  ...              94.0             108.0             114.0
#
# [5 rows x 18 columns]

# %%
def df_column_Rename(df_wide):
    df_columns = df_wide.columns
    new_columns = []
    for item in df_columns:
        counter = 0
        newitem = item
        while newitem in new_columns:
            counter += 1
            newitem = "{}_{}".format(item, counter)
        new_columns.append(newitem)
    df_wide.columns = new_columns
    return df_wide
  
df_wide = df_column_Rename(df_wide)

df_wide.rename(columns={'StationTotalFlow': 'flow_00', 'StationTotalFlow_1': 'flow_05', 'StationTotalFlow_2': 'flow_10',
                        'StationTotalFlow_3': 'flow_15', 'StationTotalFlow_4': 'flow_20', 'StationTotalFlow_5': 'flow_25',
                        'StationTotalFlow_6': 'flow_30', 'StationTotalFlow_7': 'flow_35', 'StationTotalFlow_8': 'flow_40',
                        'StationTotalFlow_9': 'flow_45', 'StationTotalFlow_10': 'flow_50', 'StationTotalFlow_11': 'flow_55'}, inplace=True)  #Change the Stationflows names to match their actual 5 min intervals

# %%
df_wide.isnull().sum()
# Out:
# StationId     0
# day           0
# month         0
# year          0
# hour          0
# dayofweek     0
# flow_00      35
# flow_05       0
# flow_10       0
# flow_15       0
# flow_20       0
# flow_25       0
# flow_30       0
# flow_35       0
# flow_40       0
# flow_45       0
# flow_50       0
# flow_55       0
# dtype: int64

# %%
df_wide['flow_00'].fillna((df_wide['flow_00'].mean()), inplace=True) #Fill Na with mean

# %%
df_wide.head()
# Out:
#    StationId  day  month  year  ...  flow_40  flow_45  flow_50  flow_55
# 0     715915    1      1  2008  ...    296.0    338.0    346.0    358.0
# 1     715915    1      1  2008  ...    369.0    367.0    359.0    318.0
# 2     715915    1      1  2008  ...    187.0    190.0    190.0    170.0
# 3     715915    1      1  2008  ...    125.0    129.0    113.0     80.0
# 4     715915    1      1  2008  ...     90.0     94.0    108.0    114.0
#
# [5 rows x 18 columns]

# %% [markdown]
# #We have successful parsed the Data

# %% [markdown]
# We normalized and divided the dataframe into training and testing to be fed to our deep neural network model.
#
# The CNN model will learn a function that maps a sequence of past observations as input to an output observation.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer

X, y = df_wide.loc[:, df_wide.columns != "flow_55"], df_wide["flow_55"]

transformer = Normalizer().fit(X)
X = transformer.transform(X)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 7984427) # Create Training and Validation Sets

# %%
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2) # Expand Dimensions for Convolutional Network

# %%
y_train = y_train.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1) # Make an Array

#y_train = sc.fit_transform(y_train)
#y_test = sc.transform(y_test)

# %%
#Best Model so far

from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Dropout, MaxPooling1D, Flatten
from keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping

print('Build model...')

modelx = keras.models.Sequential([
        keras.layers.Conv1D(filters = 64, kernel_size=3, activation='relu', input_shape=(125,1)),
        keras.layers.Conv1D(filters = 32, kernel_size=3, activation='relu'),
        keras.layers.Dropout(0.2),
        keras.layers.MaxPooling1D(pool_size = 2),
        keras.layers.Flatten(),
        keras.layers.Dense(50, activation = 'relu'),
        keras.layers.Dense(1)                        
])

modelx.compile(loss='mean_squared_error', optimizer = 'adam')
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=50, verbose=1, mode='auto', restore_best_weights=True)
print('Train...')

historyx = modelx.fit(X_train, y_train, batch_size = 100, validation_data=(X_test, y_test),
                    callbacks=[monitor], verbose=2, epochs=50)
# Out:
# Build model...
# Train...
# Train on 1398558 samples, validate on 349640 samples
# Epoch 1/50
# 1398558/1398558 - 57s - loss: 7629.2391 - val_loss: 4791.5655
# Epoch 2/50
# 1398558/1398558 - 57s - loss: 1666.4171 - val_loss: 3752.0698
# Epoch 3/50
# 1398558/1398558 - 56s - loss: 1555.0845 - val_loss: 3832.9187
# Epoch 4/50
# 1398558/1398558 - 56s - loss: 1443.9695 - val_loss: 3203.3599
# Epoch 5/50
# 1398558/1398558 - 57s - loss: 1429.2701 - val_loss: 2962.5764
# Epoch 6/50
# 1398558/1398558 - 56s - loss: 1392.2746 - val_loss: 2440.8237
# Epoch 7/50
# 1398558/1398558 - 57s - loss: 1374.7240 - val_loss: 2319.9277
# Epoch 8/50
# 1398558/1398558 - 57s - loss: 1361.6412 - val_loss: 2452.8584
# Epoch 9/50
# 1398558/1398558 - 56s - loss: 1352.0191 - val_loss: 2054.0902
# Epoch 10/50
# 1398558/1398558 - 57s - loss: 1345.7653 - val_loss: 2437.5558
# Epoch 11/50
# 1398558/1398558 - 57s - loss: 1337.6353 - val_loss: 2171.3428
# Epoch 12/50
# 1398558/1398558 - 57s - loss: 1334.7363 - val_loss: 2125.2174
# Epoch 13/50
# 1398558/1398558 - 57s - loss: 1327.1152 - val_loss: 1785.2393
# Epoch 14/50
# 1398558/1398558 - 56s - loss: 1321.6932 - val_loss: 1797.3852
# Epoch 15/50
# 1398558/1398558 - 56s - loss: 1319.0235 - val_loss: 1744.9415
# Epoch 16/50
# 1398558/1398558 - 57s - loss: 1314.6547 - val_loss: 1851.3476
# Epoch 17/50
# 1398558/1398558 - 56s - loss: 1314.1910 - val_loss: 1581.4407
# Epoch 18/50
# 1398558/1398558 - 57s - loss: 1310.8633 - val_loss: 1638.2750
# Epoch 19/50
# 1398558/1398558 - 56s - loss: 1308.6892 - val_loss: 1695.3415
# Epoch 20/50
# 1398558/1398558 - 56s - loss: 1304.0340 - val_loss: 1528.6129
# Epoch 21/50
# 1398558/1398558 - 57s - loss: 1303.6031 - val_loss: 1495.9760
# Epoch 22/50
# 1398558/1398558 - 56s - loss: 1302.3704 - val_loss: 1509.4926
# Epoch 23/50
# 1398558/1398558 - 57s - loss: 1299.8773 - val_loss: 1678.0302
# Epoch 24/50
# 1398558/1398558 - 57s - loss: 1299.1594 - val_loss: 1571.2406
# Epoch 25/50
# 1398558/1398558 - 57s - loss: 1300.6449 - val_loss: 1619.4371
# Epoch 26/50
# 1398558/1398558 - 57s - loss: 1296.3625 - val_loss: 1546.4174
# Epoch 27/50
# 1398558/1398558 - 57s - loss: 1297.4056 - val_loss: 1522.3632
# Epoch 28/50
# 1398558/1398558 - 57s - loss: 1295.6736 - val_loss: 1481.6121
# Epoch 29/50
# 1398558/1398558 - 57s - loss: 1294.6853 - val_loss: 1542.8231
# Epoch 30/50
# 1398558/1398558 - 56s - loss: 1295.1717 - val_loss: 1466.6505
# Epoch 31/50
# 1398558/1398558 - 56s - loss: 1291.6957 - val_loss: 1392.0718
# Epoch 32/50
# 1398558/1398558 - 57s - loss: 1292.3383 - val_loss: 1521.7875
# Epoch 33/50
# 1398558/1398558 - 56s - loss: 1289.9891 - val_loss: 1466.4821
# Epoch 34/50
# 1398558/1398558 - 56s - loss: 1289.0106 - val_loss: 1427.4565
# Epoch 35/50
# 1398558/1398558 - 56s - loss: 1288.8454 - val_loss: 1490.3244
# Epoch 36/50
# 1398558/1398558 - 55s - loss: 1288.7052 - val_loss: 1412.2083
# Epoch 37/50
# 1398558/1398558 - 56s - loss: 1288.6920 - val_loss: 1546.2601
# Epoch 38/50
# 1398558/1398558 - 57s - loss: 1287.5034 - val_loss: 1408.0634
# Epoch 39/50
# 1398558/1398558 - 56s - loss: 1286.9826 - val_loss: 1451.3887
# Epoch 40/50
# 1398558/1398558 - 57s - loss: 1285.3195 - val_loss: 1383.1671
# Epoch 41/50
# 1398558/1398558 - 56s - loss: 1285.9487 - val_loss: 1496.9431
# Epoch 42/50
# 1398558/1398558 - 56s - loss: 1286.3538 - val_loss: 1404.9379
# Epoch 43/50
# 1398558/1398558 - 57s - loss: 1283.7357 - val_loss: 1415.1210
# Epoch 44/50
# 1398558/1398558 - 57s - loss: 1283.2857 - val_loss: 1378.4769
# Epoch 45/50
# 1398558/1398558 - 56s - loss: 1284.1471 - val_loss: 1310.5212
# Epoch 46/50
# 1398558/1398558 - 56s - loss: 1282.9062 - val_loss: 1430.0833
# Epoch 47/50
# 1398558/1398558 - 56s - loss: 1283.3702 - val_loss: 1421.6425
# Epoch 48/50
# 1398558/1398558 - 56s - loss: 1282.4741 - val_loss: 1386.5737
# Epoch 49/50
# 1398558/1398558 - 56s - loss: 1281.5603 - val_loss: 1436.2464
# Epoch 50/50
# 1398558/1398558 - 56s - loss: 1281.4623 - val_loss: 1426.2779

# %%
# Plot an estimation of our models performance

plt.plot(historyx.history['loss'])
plt.plot(historyx.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel("Mean Square Error")
plt.title("Loss & Cost over Time")
plt.legend(["Training", "Validating"])

# %%
from sklearn import metrics
pred = modelx.predict(X_test)
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Score (RMSE): {}".format(score)) # Rmse to compare with the standard deviation of our target variable(flow_55) which is 150

mae = metrics.mean_absolute_error(pred, y_test)
print("Score (MAE): {}".format(mae))
# Out:
# Score (RMSE): 37.76241812845421
# Score (MAE): 27.030239521610206

# %% [markdown]
# We have shown a cnn with are training data normalized.  This is a technique used in practice for temporial data+cnn but it is not desirable.  Using this method we are saying that the day of the month aka 7 is less than the day of the month 8... this is not true.  This same concept can be thought for
#
# StationId, day, month, year, hour, and dayofweek

# %% [markdown]
# Are more ideal way to represent time patterns is to apply fourier transforms to our data or one-hot encoding.  There are better algorithms to use than cnn for these methods.

# %% [markdown]
# That's a lot a values to encode...
# What's a good way to go about this...

# %% [markdown]
# **PART 2**

# %% [markdown]
# After doing some research... we have decided to see how well deep encoding will help us in our exploration

# %%
dfy = df_wide

# %%
dfy.head()
# Out:
#    StationId  day  month  year  ...  flow_40  flow_45  flow_50  flow_55
# 0     715915    1      1  2008  ...    296.0    338.0    346.0    358.0
# 1     715915    1      1  2008  ...    369.0    367.0    359.0    318.0
# 2     715915    1      1  2008  ...    187.0    190.0    190.0    170.0
# 3     715915    1      1  2008  ...    125.0    129.0    113.0     80.0
# 4     715915    1      1  2008  ...     90.0     94.0    108.0    114.0
#
# [5 rows x 18 columns]

# %%
dfy = pd.concat([dfy, pd.get_dummies(dfy["StationId"], prefix = "Station_")], axis = 1)
dfy = pd.concat([dfy, pd.get_dummies(dfy["day"], prefix = "day_")], axis = 1)
dfy = pd.concat([dfy, pd.get_dummies(dfy["month"], prefix = "month_")], axis = 1)
dfy = pd.concat([dfy, pd.get_dummies(dfy["year"], prefix = "year_")], axis = 1)
dfy = pd.concat([dfy, pd.get_dummies(dfy["hour"], prefix = "hour_")], axis = 1)
dfy = pd.concat([dfy, pd.get_dummies(dfy["dayofweek"], prefix = "dayofweek_")], axis = 1)

dfy = dfy.drop(['StationId', 'day', 'month', 'year', 'hour', 'dayofweek'], axis=1)

# %%
dfy.head()
# Out:
#    flow_00  flow_05  flow_10  ...  dayofweek__5  dayofweek__6  dayofweek__7
# 0     82.0     78.0     95.0  ...             0             0             0
# 1    396.0    358.0    394.0  ...             0             0             0
# 2    324.0    204.0    218.0  ...             0             0             0
# 3    164.0    177.0    148.0  ...             0             0             0
# 4     96.0     80.0    102.0  ...             0             0             0
#
# [5 rows x 126 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer

X, y = dfy.loc[:, dfy.columns != "flow_55"], dfy["flow_55"]

transformer = Normalizer().fit(X)
X = transformer.transform(X)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 7984427) # Create Training and Validation Sets

# %%
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2) # Expand Dimensions for Convolutional Network

# %%
y_train = y_train.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1) # Make an Array

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1398558, 125, 1), (349640, 125, 1), (1398558, 1), (349640, 1))

# %%
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Dropout, MaxPooling1D, Flatten
from keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping


model = keras.models.Sequential([
        keras.layers.Conv1D(filters = 64, kernel_size=3, activation='relu', input_shape=(125,1)),
        keras.layers.Conv1D(filters = 32, kernel_size=3, activation='relu'),
        keras.layers.Dropout(0.2),
        keras.layers.MaxPooling1D(pool_size = 2),
        keras.layers.Flatten(),
        keras.layers.Dense(50, activation = 'relu'),
        keras.layers.Dense(1)                        
])


model.compile(loss='mean_squared_error', optimizer = 'adam')
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=50, verbose=1, mode='auto', restore_best_weights=True)
print('Train...')

history = model.fit(X_train, y_train, batch_size=100, validation_data=(X_test, y_test),
                    callbacks=[monitor], verbose=2, epochs=50)
# Out:
# Train...
# Train on 1398558 samples, validate on 349640 samples
# Epoch 1/50
# 1398558/1398558 - 59s - loss: 15856.8296 - val_loss: 14706.3766
# Epoch 2/50
# 1398558/1398558 - 57s - loss: 8752.5791 - val_loss: 6422.8827
# Epoch 3/50
# 1398558/1398558 - 57s - loss: 2942.4070 - val_loss: 3267.1637
# Epoch 4/50
# 1398558/1398558 - 58s - loss: 1937.8223 - val_loss: 2501.3782
# Epoch 5/50
# 1398558/1398558 - 57s - loss: 1527.3174 - val_loss: 2757.1097
# Epoch 6/50
# 1398558/1398558 - 58s - loss: 1378.3868 - val_loss: 2232.3301
# Epoch 7/50
# 1398558/1398558 - 58s - loss: 1311.9952 - val_loss: 2246.8529
# Epoch 8/50
# 1398558/1398558 - 57s - loss: 1260.2783 - val_loss: 1393.0718
# Epoch 9/50
# 1398558/1398558 - 58s - loss: 1226.1356 - val_loss: 1252.1038
# Epoch 10/50
# 1398558/1398558 - 57s - loss: 1201.4312 - val_loss: 2012.9167
# Epoch 11/50
# 1398558/1398558 - 57s - loss: 1178.2709 - val_loss: 1870.5937
# Epoch 12/50
# 1398558/1398558 - 57s - loss: 1155.3550 - val_loss: 1227.9053
# Epoch 13/50
# 1398558/1398558 - 56s - loss: 1136.6409 - val_loss: 1422.2765
# Epoch 14/50
# 1398558/1398558 - 57s - loss: 1121.4438 - val_loss: 1019.4510
# Epoch 15/50
# 1398558/1398558 - 58s - loss: 1107.3952 - val_loss: 1134.6582
# Epoch 16/50
# 1398558/1398558 - 57s - loss: 1097.2199 - val_loss: 1134.2132
# Epoch 17/50
# 1398558/1398558 - 57s - loss: 1088.5533 - val_loss: 1049.9169
# Epoch 18/50
# 1398558/1398558 - 57s - loss: 1081.6622 - val_loss: 1035.7111
# Epoch 19/50
# 1398558/1398558 - 57s - loss: 1074.0775 - val_loss: 1000.4477
# Epoch 20/50
# 1398558/1398558 - 58s - loss: 1067.1555 - val_loss: 1178.7904
# Epoch 21/50
# 1398558/1398558 - 56s - loss: 1060.0368 - val_loss: 1023.8387
# Epoch 22/50
# 1398558/1398558 - 57s - loss: 1052.9013 - val_loss: 1058.0913
# Epoch 23/50
# 1398558/1398558 - 56s - loss: 1047.9137 - val_loss: 1002.8783
# Epoch 24/50
# 1398558/1398558 - 56s - loss: 1041.9017 - val_loss: 997.7394
# Epoch 25/50
# 1398558/1398558 - 56s - loss: 1037.6302 - val_loss: 1183.2236
# Epoch 26/50
# 1398558/1398558 - 57s - loss: 1032.2267 - val_loss: 995.0177
# Epoch 27/50
# 1398558/1398558 - 57s - loss: 1027.5685 - val_loss: 960.0065
# Epoch 28/50
# 1398558/1398558 - 57s - loss: 1024.8944 - val_loss: 1027.1771
# Epoch 29/50
# 1398558/1398558 - 56s - loss: 1019.7245 - val_loss: 1138.7862
# Epoch 30/50
# 1398558/1398558 - 57s - loss: 1018.3316 - val_loss: 957.9227
# Epoch 31/50
# 1398558/1398558 - 57s - loss: 1015.9748 - val_loss: 948.2099
# Epoch 32/50
# 1398558/1398558 - 57s - loss: 1010.7008 - val_loss: 955.4634
# Epoch 33/50
# 1398558/1398558 - 57s - loss: 1008.4412 - val_loss: 953.6135
# Epoch 34/50
# 1398558/1398558 - 57s - loss: 1006.0470 - val_loss: 1003.2217
# Epoch 35/50
# 1398558/1398558 - 57s - loss: 1003.7007 - val_loss: 1000.3372
# Epoch 36/50
# 1398558/1398558 - 57s - loss: 1003.7836 - val_loss: 935.3061
# Epoch 37/50
# 1398558/1398558 - 58s - loss: 1000.5279 - val_loss: 987.7271
# Epoch 38/50
# 1398558/1398558 - 57s - loss: 999.1228 - val_loss: 947.3545
# Epoch 39/50
# 1398558/1398558 - 57s - loss: 996.4731 - val_loss: 1016.9257
# Epoch 40/50
# 1398558/1398558 - 57s - loss: 993.8574 - val_loss: 986.6144
# Epoch 41/50
# 1398558/1398558 - 56s - loss: 994.7602 - val_loss: 958.0561
# Epoch 42/50
# 1398558/1398558 - 57s - loss: 988.7646 - val_loss: 1183.3734
# Epoch 43/50
# 1398558/1398558 - 57s - loss: 989.8588 - val_loss: 953.2924
# Epoch 44/50
# 1398558/1398558 - 56s - loss: 988.0596 - val_loss: 943.7903
# Epoch 45/50
# 1398558/1398558 - 56s - loss: 984.3111 - val_loss: 943.1948
# Epoch 46/50
# 1398558/1398558 - 56s - loss: 984.5845 - val_loss: 973.0890
# Epoch 47/50
# 1398558/1398558 - 56s - loss: 981.6192 - val_loss: 1049.5432
# Epoch 48/50
# 1398558/1398558 - 57s - loss: 982.4860 - val_loss: 938.4866
# Epoch 49/50
# 1398558/1398558 - 57s - loss: 980.6003 - val_loss: 935.5069
# Epoch 50/50
# 1398558/1398558 - 57s - loss: 978.2917 - val_loss: 1025.4066

# %%
# Plot an estimation of our models performance

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel("Mean Square Error")
plt.title("Loss & Cost over Time")
plt.legend(["Training", "Validating"])

# %%
from sklearn import metrics
predx = model.predict(X_test)
score = np.sqrt(metrics.mean_squared_error(predx,y_test))
print("Score (RMSE): {}".format(score)) # Rmse to compare with the standard deviation of our target variable(flow_55) which is 150

mae = metrics.mean_absolute_error(predx, y_test)
print("Score (MAE): {}".format(mae))
# Out:
# Score (RMSE): 32.02196982175541
# Score (MAE): 22.554011659774392

# %%
#from matplotlib import pyplot
#pyplot.plot(y_test)
#pyplot.plot(predx, color='red')
#pyplot.show()

# %% [markdown]
# Building a DNN Network

# %%
model = keras.models.Sequential([
        keras.layers.Dense(85, activation='relu', input_shape = X_train.shape[1:]),
        keras.layers.Dense(425, activation='relu'),
        keras.layers.Dense(425, activation = 'relu'),
        keras.layers.Dense(85, activation = 'relu'),
        keras.layers.Dense(1)                        
])

model.compile(loss='mean_squared_error', optimizer = 'adam')
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=50, verbose=1, mode='auto', restore_best_weights=True)
print('Train...')

history = model.fit(X_train, y_train, batch_size=100, validation_data=(X_test, y_test),
                    callbacks=[monitor], verbose=2, epochs=50)
# Out:
# Train...
# Train on 1398558 samples, validate on 349640 samples
# Epoch 1/50
# 1398558/1398558 - 51s - loss: 2519.8151 - val_loss: 2057.2970
# Epoch 2/50
# 1398558/1398558 - 49s - loss: 1189.2733 - val_loss: 1253.8549
# Epoch 3/50
# 1398558/1398558 - 49s - loss: 1127.5249 - val_loss: 1359.3151
# Epoch 4/50
# 1398558/1398558 - 50s - loss: 1085.4336 - val_loss: 1273.5754
# Epoch 5/50
# 1398558/1398558 - 50s - loss: 1056.0727 - val_loss: 1037.9535
# Epoch 6/50
# 1398558/1398558 - 49s - loss: 1038.2727 - val_loss: 951.3791
# Epoch 7/50
# 1398558/1398558 - 50s - loss: 1031.3236 - val_loss: 1134.9345
# Epoch 8/50
# 1398558/1398558 - 50s - loss: 1019.4807 - val_loss: 961.6702
# Epoch 9/50
# 1398558/1398558 - 49s - loss: 1013.6356 - val_loss: 945.7361
# Epoch 10/50
# 1398558/1398558 - 49s - loss: 1004.6275 - val_loss: 977.0380
# Epoch 11/50
# 1398558/1398558 - 50s - loss: 999.9562 - val_loss: 1014.8240
# Epoch 12/50
# 1398558/1398558 - 50s - loss: 993.8070 - val_loss: 1097.9785
# Epoch 13/50
# 1398558/1398558 - 51s - loss: 985.5150 - val_loss: 1162.6470
# Epoch 14/50
# 1398558/1398558 - 50s - loss: 983.4311 - val_loss: 1234.7443
# Epoch 15/50
# 1398558/1398558 - 50s - loss: 978.9464 - val_loss: 994.2088
# Epoch 16/50
# 1398558/1398558 - 50s - loss: 971.4512 - val_loss: 976.3275
# Epoch 17/50
# 1398558/1398558 - 50s - loss: 969.6494 - val_loss: 1017.4628
# Epoch 18/50
# 1398558/1398558 - 50s - loss: 966.6555 - val_loss: 956.0796
# Epoch 19/50
# 1398558/1398558 - 50s - loss: 965.8759 - val_loss: 1227.1764
# Epoch 20/50
# 1398558/1398558 - 51s - loss: 964.4877 - val_loss: 914.6650
# Epoch 21/50
# 1398558/1398558 - 50s - loss: 955.5899 - val_loss: 1071.9091
# Epoch 22/50
# 1398558/1398558 - 50s - loss: 953.3444 - val_loss: 909.1231
# Epoch 23/50
# 1398558/1398558 - 51s - loss: 951.1169 - val_loss: 1031.2369
# Epoch 24/50
# 1398558/1398558 - 50s - loss: 949.2164 - val_loss: 944.8756
# Epoch 25/50
# 1398558/1398558 - 50s - loss: 947.0825 - val_loss: 920.9464
# Epoch 26/50
# 1398558/1398558 - 51s - loss: 947.2557 - val_loss: 911.3756
# Epoch 27/50
# 1398558/1398558 - 50s - loss: 942.7651 - val_loss: 907.7088
# Epoch 28/50
# 1398558/1398558 - 51s - loss: 941.2136 - val_loss: 909.5027
# Epoch 29/50
# 1398558/1398558 - 51s - loss: 941.4917 - val_loss: 935.1684
# Epoch 30/50
# 1398558/1398558 - 50s - loss: 938.0176 - val_loss: 906.0728
# Epoch 31/50
# 1398558/1398558 - 51s - loss: 937.1048 - val_loss: 941.9998
# Epoch 32/50
# 1398558/1398558 - 51s - loss: 933.7918 - val_loss: 922.4039
# Epoch 33/50
# 1398558/1398558 - 51s - loss: 934.1087 - val_loss: 899.7190
# Epoch 34/50
# 1398558/1398558 - 50s - loss: 929.8751 - val_loss: 921.0237
# Epoch 35/50
# 1398558/1398558 - 51s - loss: 928.8074 - val_loss: 947.1999
# Epoch 36/50
# 1398558/1398558 - 51s - loss: 928.5222 - val_loss: 922.7556
# Epoch 37/50
# 1398558/1398558 - 51s - loss: 925.8545 - val_loss: 1030.0855
# Epoch 38/50
# 1398558/1398558 - 52s - loss: 925.0371 - val_loss: 1027.4315
# Epoch 39/50
# 1398558/1398558 - 51s - loss: 925.3073 - val_loss: 932.8638
# Epoch 40/50
# 1398558/1398558 - 51s - loss: 923.9001 - val_loss: 928.9125
# Epoch 41/50
# 1398558/1398558 - 51s - loss: 922.0072 - val_loss: 1013.9885
# Epoch 42/50
# 1398558/1398558 - 51s - loss: 920.5603 - val_loss: 1113.6058
# Epoch 43/50
# 1398558/1398558 - 51s - loss: 922.8021 - val_loss: 1000.2623
# Epoch 44/50
# 1398558/1398558 - 52s - loss: 917.7670 - val_loss: 902.7739
# Epoch 45/50
# 1398558/1398558 - 51s - loss: 915.1928 - val_loss: 1003.4021
# Epoch 46/50
# 1398558/1398558 - 51s - loss: 915.1553 - val_loss: 905.1716
# Epoch 47/50
# 1398558/1398558 - 51s - loss: 914.4879 - val_loss: 903.2474
# Epoch 48/50
# 1398558/1398558 - 51s - loss: 911.9299 - val_loss: 900.3088
# Epoch 49/50
# 1398558/1398558 - 51s - loss: 913.2249 - val_loss: 927.4058
# Epoch 50/50
# 1398558/1398558 - 52s - loss: 910.6565 - val_loss: 899.0216

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel("Mean Square Error")
plt.title("Loss & Cost over Time")
plt.legend(["Training", "Validating"])

# %%
predz = model.predict(X_test)
score = np.sqrt(metrics.mean_squared_error(predz,y_test))
print("Score (RMSE): {}".format(score)) # Rmse to compare with the standard deviation of our target variable(flow_55) which is 150

mae = metrics.mean_absolute_error(predx, y_test)
print("Score (MAE): {}".format(mae))
# Out:
# Score (RMSE): 29.983688259758743
# Score (MAE): 22.554011659774392

# %% [markdown]
# Building a DNN using the functional Api

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer

X, y = dfy.loc[:, dfy.columns != "flow_55"], dfy["flow_55"]

transformer = Normalizer().fit(X)
X = transformer.transform(X)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 7984427) # Create Training and Validation Sets

y_train = y_train.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1) # Make an Array

# %%
input_A = keras.layers.Input(shape=[11], name="wide_input")
input_B = keras.layers.Input(shape=[124], name="deep_input")
hidden1 = keras.layers.Dense(425, activation="relu")(input_B)
hidden2 = keras.layers.Dense(85, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_A, hidden2])
output = keras.layers.Dense(1, name="output")(concat)
model = keras.models.Model(inputs=[input_A, input_B], outputs=[output])


model.compile(loss='mean_squared_error', optimizer = 'adam')

X_train_A, X_train_B = X_train[:, :11], X_train[:, 1:]
X_test_A, X_test_B = X_test[:, :11], X_test[:, 1:]

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=50,
                        verbose=1, mode='auto', restore_best_weights=True)
print('Train...')

history = model.fit((X_train_A, X_train_B), y_train, batch_size=500,
          validation_data=((X_test_A, X_test_B), y_test),
           callbacks=[monitor], verbose=2, epochs=50)

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel("Mean Square Error")
plt.title("Loss & Cost over Time")
plt.legend(["Training", "Validating"])
